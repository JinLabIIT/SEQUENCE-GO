# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
data_path = './data/data2.txt'
df = pd.read_csv(data_path, header=None)
df.columns = ['time', 'event_number']
df.insert(2, 'thread_number', 1)

# %%
df
# Out:
#                  time  event_number  thread_number
# 0           421954758        498081              1
# 1           586043353        227887              1
# 2           677225901        131847              1
# 3          1016230869        484059              1
# 4          1275176762        402081              1
# ...               ...           ...            ...
# 66611  10909721241144        332641              1
# 66612  10909749698285         46759              1
# 66613  10910035496735        423775              1
# 66614  10910258193466        350292              1
# 66615  10910511558624        404284              1
#
# [66616 rows x 3 columns]

# %%
plt.hist(df['event_number'], density=True, bins=10)  # `density=False` would make counts
plt.ylabel('Probability')
plt.xlabel('Number of Event');

# %%
sample_ratio = 0.01
df_sample = df.sample(frac=sample_ratio)
plt.scatter(df_sample['event_number'], df_sample['time'])
plt.title('sampling = {}'.format(sample_ratio))
plt.ylabel('Time(ns)')
plt.xlabel('Number of Event');
plt.show()

# %%
maximum, minimum = df['event_number'].max(), df['event_number'].min()
number_bin = 10
    
    

fig = plt.figure()
# Create an axes instance
ax = fig.add_axes([0,0,1,1])
# Create the boxplot
bp = ax.boxplot([df[col_name] for df in list_df], showfliers=False)
ax.legend([ '{}: dataset{}'.format(i, i) for i in range(1,6)] + ['6: Full Set'], bbox_to_anchor=(1.1, 1))
plt.show()

# %%
data_path = './data/ExceTime.txt'
df = pd.read_csv(data_path, header=None)
df.columns = ['time', 'event_number', 'thread_number']

# %%
df

# %%
thread_num = 16
df = df[df['thread_number'] == thread_num]

# %%
plt.hist(df['event_number'], density=True, bins=10)  # `density=False` would make counts
plt.ylabel('Probability')
plt.xlabel('Number of Event');

# %%
sample_ratio = 1
df_sample = df.sample(frac=sample_ratio)
plt.scatter(df_sample['event_number'], df_sample['time'], s=1)
plt.title('sampling = {} | thread = {}'.format(sample_ratio, thread_num))
plt.ylabel('Time(ns)')
plt.xlabel('Number of Event');
plt.show()

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)


N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=1)
plt.show()
